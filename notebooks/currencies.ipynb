# %%
import pandas as pd
pd.read_parquet("../data/bronze/currencies")
# Out:
#       id                           name short_code code  precision  subunit  \
# 0      1                     UAE Dirham        AED  784          2      100
# 1      2                        Afghani        AFN  971          2      100
# 2      3                            Lek        ALL    8          2      100
# 3      4                  Armenian Dram        AMD   51          2      100
# 4      5  Netherlands Antillean Guilder        ANG  532          2      100
# ..   ...                            ...        ...  ...        ...      ...
# 478  157                      CFP Franc        XPF  953          0        1
# 479  158                    Yemeni Rial        YER  886          2      100
# 480  159                           Rand        ZAR  710          2      100
# 481  160                 Zambian Kwacha        ZMW  967          2      100
# 482  161                Zimbabwe Dollar        ZWL  932          2      100
#
# ...

# %%
import pandas as pd
pd.read_parquet("../data/bronze/rates")
# Out:
#       currency            rate           rate_date               _ingested_at  \
# 0          SOS  155.6070039800 2026-03-29 08:38:44 2026-03-29 08:39:08.612998
# 1          BBD    0.5445881600 2026-03-29 08:38:44 2026-03-29 08:39:08.612998
# 2          SDG  163.4289028300 2026-03-29 08:38:44 2026-03-29 08:39:08.612998
# 3          AWG    0.4874064000 2026-03-29 08:38:44 2026-03-29 08:39:08.612998
# 4          BIF  808.2374107100 2026-03-29 08:38:44 2026-03-29 08:39:08.612998
# ...        ...             ...                 ...                        ...
# 76795      ERN    0.0002365600 2026-03-29 08:39:00 2026-03-29 08:39:08.612998
# 76796      ALL    0.0013145000 2026-03-29 08:39:00 2026-03-29 08:39:08.612998
# 76797      GNF    0.1384633200 2026-03-29 08:39:00 2026-03-29 08:39:08.612998
# 76798      PGK    0.0000678600 2026-03-29 08:39:00 2026-03-29 08:39:08.612998
# 76799      SLL    0.3608371700 2026-03-29 08:39:00 2026-03-29 08:39:08.612998
#
# ...

# %%
import pandas as pd
pd.read_parquet("../data/silver/currencies")
# Out:
#        id                           name short_code code  precision  subunit  \
# 0       1                     UAE Dirham        AED  784          2      100
# 1       2                        Afghani        AFN  971          2      100
# 2       3                            Lek        ALL  008          2      100
# 3       4                  Armenian Dram        AMD  051          2      100
# 4       5  Netherlands Antillean Guilder        ANG  532          2      100
# ...   ...                            ...        ...  ...        ...      ...
# 1283  157                      CFP Franc        XPF  953          0        1
# 1284  158                    Yemeni Rial        YER  886          2      100
# 1285  159                           Rand        ZAR  710          2      100
# 1286  160                 Zambian Kwacha        ZMW  967          2      100
# 1287  161                Zimbabwe Dollar        ZWL  932          2      100
#
# ...

# %%
import os
import pandas as pd

if os.path.exists('../data/silver/currencies_quarantine'):
    pd.read_parquet('../data/silver/currencies_quarantine')
else:
    print('No currency quarantine data')
# Out:
# No currency quarantine data

# %%
import pandas as pd
pd.read_parquet("../data/silver/rates")
# Out:
#        currency            rate           rate_date  \
# 0           MWK  472.6034663400 2026-03-19 19:20:04
# 1           GEL    0.7409335200 2026-03-19 19:20:04
# 2           BWP    3.7102857200 2026-03-19 19:20:04
# 3           JMD   42.7824352200 2026-03-19 19:20:04
# 4           HUF   91.7679185200 2026-03-19 19:20:04
# ...         ...             ...                 ...
# 230395      UGX    0.0588313500 2026-03-29 17:01:07
# 230396      SYP    0.0017430800 2026-03-29 17:01:07
# 230397      CAD    0.0000218500 2026-03-29 17:01:07
# 230398      SGD    0.0000203200 2026-03-29 17:01:07
# 230399      CLF        3.700E-7 2026-03-29 17:01:07
#
#                      _ingested_at                              _source_file  \
# 0      2026-03-19 19:20:27.146804  https://api.currencybeacon.com/v1/latest
# 1      2026-03-19 19:20:27.146804  https://api.currencybeacon.com/v1/latest
# 2      2026-03-19 19:20:27.146804  https://api.currencybeacon.com/v1/latest
# ...

# %%
import os
import pandas as pd

if os.path.exists('../data/silver/rates_quarantine'):
    pd.read_parquet('../data/silver/rates_quarantine')
else:
    print('No rates quarantine data')
# Out:
# No rates quarantine data
